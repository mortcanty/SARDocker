# %%
# !/home/sar_seq.sh 20090525 20090618 20090712 20090805 20090829 20091016 [200,200,1000,1000] 12 0.01
# Out:
# ***** Multitemporal PolSAR Change Detection **********
# ******************************************************
# number of images    6
# ENL                 12
# spatial subset      [200,200,1000,1000]
# significance level  0.01
# ...
#      Register SAR
# ...
# Fri Feb 26 14:02:18 2016
# Reference image:
#  /home/imagery/RS2_OK5491_PK71074_DK68879_FQ21_20090525_172447_HH_VV_HV_VH_SLC_MapReady/T3/polSAR.tif
# Target image:
#  /home/imagery/RS2_OK5491_PK71075_DK68880_FQ21_20090618_172447_HH_VV_HV_VH_SLC_MapReady/T3/polSAR.tif
# warping 9 bands (quad pol)...
# elapsed time: 13.0101320744
# Warped image written to: /home/imagery/RS2_OK5491_PK71075_DK68880_FQ21_20090618_172447_HH_VV_HV_VH_SLC_MapReady/T3/polSAR_warp.tif
# ...
#      Register SAR
# ...
# Fri Feb 26 14:02:31 2016
# Reference image:
#  /home/imagery/RS2_OK5491_PK71074_DK68879_FQ21_20090525_172447_HH_VV_HV_VH_SLC_MapReady/T3/polSAR.tif
# Target image:
# ...

# %%
# %matplotlib inline

# %%
run /home/dispms   -d [600,300,200,200] -C [4,5] -E 2 -D [600,300,200,200] -o 0.5 \
-f /home/imagery/RS2_OK5491_PK71074_DK68879_FQ21_20090525_172447_HH_VV_HV_VH_SLC_MapReady/T3/polSAR_sub.tif \
-F /home/imagery/RS2_OK5491_PK71074_DK68879_FQ21_20090525_172447_HH_VV_HV_VH_SLC_MapReady/T3/sarseq(20090525-4-20091016)_fmap.tif
