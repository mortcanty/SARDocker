# %%
cd imagery
# Out:
# /home/imagery

# %%
ls -l
# Out:
# total 900
# drwxrwxr-x 8 1000 1000   4096 Feb 29 11:00 TDX1_SAR__SSC______HS_S_SRA_20120216T170934_20120216T170935/
# drwxrwxr-x 8 1000 1000   4096 Feb 29 11:02 TDX1_SAR__SSC______HS_S_SRA_20120331T170935_20120331T170936/
# drwxrwxr-x 8 1000 1000   4096 Feb 29 11:03 TDX1_SAR__SSC______HS_S_SRA_20120422T170936_20120422T170937/
# drwxrwxr-x 8 1000 1000   4096 Feb 29 10:58 TDX1_SAR__SSC______HS_S_SRA_20120719T170940_20120719T170941/
# drwxrwxr-x 8 1000 1000   4096 Feb 29 11:05 TDX1_SAR__SSC______HS_S_SRA_20120901T170942_20120901T170943/
# drwxrwxr-x 8 1000 1000   4096 Feb 29 11:06 TDX1_SAR__SSC______HS_S_SRA_20121015T170942_20121015T170943/
# drwxrwxr-x 8 1000 1000   4096 Feb 29 11:08 TDX1_SAR__SSC______HS_S_SRA_20121106T170942_20121106T170943/
# drwxrwxr-x 8 1000 1000   4096 Feb 29 11:09 TDX1_SAR__SSC______HS_S_SRA_20121128T170941_20121128T170942/
# drwxrwxr-x 8 1000 1000   4096 Feb 29 11:10 TDX1_SAR__SSC______HS_S_SRA_20121220T170940_20121220T170941/
# ...

# %%
# %matplotlib inline

# %%
run /home/dispms -f /home/imagery/TDX1_SAR__SSC______HS_S_SRA_20120216T170934_20120216T170935/C1/Intensity_HH.bin

# %%
run /home/dispms -d [2100,700,700,700] -f /home/imagery/TDX1_SAR__SSC______HS_S_SRA_20120216T170934_20120216T170935/C1/Intensity_HH.bin

# %%
# !/home/sar_seq_tsx.sh 20120216 20120320 20120331 20120411 20120422 \
[2100,700,700,700] 20 0.01
# Out:
# ***** Multitemporal PolSAR Change Detection **********
# ***** Terra-SAR-X singlepol imagery ******************
# ******************************************************
# number of images  5
# ENL               20
# spatial subset    [2100,700,700,700]
# ...
#      Register SAR
# ...
# Wed Apr 27 12:40:49 2016
# Reference image:
#  /home/imagery/TDX1_SAR__SSC______HS_S_SRA_20120216T170934_20120216T170935/C1/Intensity_HH.bin
# Target image:
#  /home/imagery/TSX1_SAR__SSC______HS_S_SRA_20120320T170934_20120320T170935/C1/Intensity_HH.bin
# warping 1 band (single pol)...
# elapsed time: 5.38748979568
# Warped image written to: /home/imagery/TSX1_SAR__SSC______HS_S_SRA_20120320T170934_20120320T170935/C1/Intensity_HH_warp.bin
# ...
#      Register SAR
# ...
# Wed Apr 27 12:40:54 2016
# Reference image:
#  /home/imagery/TDX1_SAR__SSC______HS_S_SRA_20120216T170934_20120216T170935/C1/Intensity_HH.bin
# Target image:
#  /home/imagery/TDX1_SAR__SSC______HS_S_SRA_20120331T170935_20120331T170936/C1/Intensity_HH.bin
# ...

# %%
run /home/dispms -c [1,2,3,4,5,6,7,8] -e 2 \
-f /home/imagery/TDX1_SAR__SSC______HS_S_SRA_20120216T170934_20120216T170935/C1/sarseq(20120216-3-20120422)_cmap.tif \
-o 0.5 \
-F /home/imagery/TDX1_SAR__SSC______HS_S_SRA_20120216T170934_20120216T170935/C1/Intensity_HH_sub.bin

# %%
# !/home/sar_seq_tsx.sh 20120708 20120719 20120730 20120821 20120901 20121015 20121106 20121128 20121220 \
[2100,700,700,700] 20 0.01
# Out:
# ***** Multitemporal PolSAR Change Detection **********
# ***** Terra-SAR-X singlepol imagery ******************
# ******************************************************
# number of images  9
# ENL               20
# spatial subset    [2100,700,700,700]
# ...
#      Register SAR
# ...
# Wed Apr 27 12:42:18 2016
# Reference image:
#  /home/imagery/TSX1_SAR__SSC______HS_S_SRA_20120708T170939_20120708T170940/C1/Intensity_HH.bin
# Target image:
#  /home/imagery/TDX1_SAR__SSC______HS_S_SRA_20120719T170940_20120719T170941/C1/Intensity_HH.bin
# warping 1 band (single pol)...
# elapsed time: 5.69721913338
# Warped image written to: /home/imagery/TDX1_SAR__SSC______HS_S_SRA_20120719T170940_20120719T170941/C1/Intensity_HH_warp.bin
# ...
#      Register SAR
# ...
# Wed Apr 27 12:42:24 2016
# Reference image:
#  /home/imagery/TSX1_SAR__SSC______HS_S_SRA_20120708T170939_20120708T170940/C1/Intensity_HH.bin
# Target image:
#  /home/imagery/TSX1_SAR__SSC______HS_S_SRA_20120730T170941_20120730T170941/C1/Intensity_HH.bin
# ...

# %%
run /home/dispms -c [1,2,3,4,5,6,7,8] -e 2 \
-f /home/imagery/TSX1_SAR__SSC______HS_S_SRA_20120708T170939_20120708T170940/C1/sarseq(20120708-7-20121220)_fmap.tif \
-F /home/imagery/TSX1_SAR__SSC______HS_S_SRA_20120708T170939_20120708T170940/C1/Intensity_HH_sub.bin
